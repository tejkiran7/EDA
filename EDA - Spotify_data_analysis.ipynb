# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\TEJKIRAN\Desktop\DataAnalytics_files\spotify_data.csv")
df.drop("Unnamed: 0",axis=1,inplace=True)
df
# Out:
#       acousticness  danceability  duration_ms  energy  instrumentalness  key  \
# 0          0.01020         0.833       204600   0.434          0.021900    2
# 1          0.19900         0.743       326933   0.359          0.006110    1
# 2          0.03440         0.838       185707   0.412          0.000234    2
# 3          0.60400         0.494       199413   0.338          0.510000    5
# 4          0.18000         0.678       392893   0.561          0.512000    5
# ...            ...           ...          ...     ...               ...  ...
# 2012       0.00106         0.584       274404   0.932          0.002690    1
# 2013       0.08770         0.894       182182   0.892          0.001670    1
# 2014       0.00857         0.637       207200   0.935          0.003990    0
# 2015       0.00164         0.557       185600   0.992          0.677000    1
# 2016       0.00281         0.446       204520   0.915          0.000039    9
#
# ...

# %%
df.shape
# Out:
# (2017, 16)

# %%
df.isna().sum()
# Out:
# acousticness        0
# danceability        0
# duration_ms         0
# energy              0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# speechiness         0
# tempo               0
# time_signature      0
# valence             0
# target              0
# song_title          0
# artist              0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2017 entries, 0 to 2016
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   acousticness      2017 non-null   float64
#  1   danceability      2017 non-null   float64
#  2   duration_ms       2017 non-null   int64
#  3   energy            2017 non-null   float64
#  4   instrumentalness  2017 non-null   float64
#  5   key               2017 non-null   int64
#  6   liveness          2017 non-null   float64
#  7   loudness          2017 non-null   float64
#  8   mode              2017 non-null   int64
#  9   speechiness       2017 non-null   float64
#  10  tempo             2017 non-null   float64
#  11  time_signature    2017 non-null   float64
#  12  valence           2017 non-null   float64
#  13  target            2017 non-null   int64
#  14  song_title        2017 non-null   object
#  15  artist            2017 non-null   object
# ...

# %%
df.columns
# Out:
# Index(['acousticness', 'danceability', 'duration_ms', 'energy',
#        'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
#        'speechiness', 'tempo', 'time_signature', 'valence', 'target',
#        'song_title', 'artist'],
#       dtype='object')

# %%
df.describe().transpose()
# Out:
#                    count           mean           std           min  \
# acousticness      2017.0       0.187590      0.259989      0.000003
# danceability      2017.0       0.618422      0.161029      0.122000
# duration_ms       2017.0  246306.197323  81981.814219  16042.000000
# energy            2017.0       0.681577      0.210273      0.014800
# instrumentalness  2017.0       0.133286      0.273162      0.000000
# key               2017.0       5.342588      3.648240      0.000000
# liveness          2017.0       0.190844      0.155453      0.018800
# loudness          2017.0      -7.085624      3.761684    -33.097000
# mode              2017.0       0.612295      0.487347      0.000000
# speechiness       2017.0       0.092664      0.089931      0.023100
# tempo             2017.0     121.603272     26.685604     47.859000
# time_signature    2017.0       3.968270      0.255853      1.000000
# valence           2017.0       0.496815      0.247195      0.034800
# ...

# %% [markdown]
# <h1><b>Observation</b><br></h1>
# Seems Like our dataset is pretty clean, we can move with Analyzing the Data

# %% [markdown]
# ### Top 5 most popular artists

# %%
top_five_artists = df.groupby("artist").count().sort_values(by="song_title",ascending=False)["song_title"][:5]
top_five_artists
# Out:
# artist
# Drake              16
# Rick Ross          13
# Disclosure         12
# Backstreet Boys    10
# WALK THE MOON      10
# Name: song_title, dtype: int64

# %%
top_five_artists.plot.barh()
# Out:
# <AxesSubplot:ylabel='artist'>

# %% [markdown]
# ### Top 5 loudest tracks

# %%
top_5_loudest_tracks = df[["loudness","song_title"]].sort_values(by="loudness",ascending=True)[:5]
top_5_loudest_tracks
# Out:
#       loudness                                         song_title
# 1594   -33.097            Lyric Pieces, Book I Op. 12: I. Arietta
# 1596   -31.367            8 Fantasiestücke, Op.12 : 1. Des Abends
# 1598   -31.082  Piano Quartet in E flat, Op.47: 3. Andante can...
# 1531   -30.447          I Was So Young, and You Were So Beautiful
# 1549   -29.460                                            Eleanor

# %%
plt.figure(figsize = (10, 5))
sns.barplot(y="song_title",x="loudness",data=top_5_loudest_tracks)
plt.title("Top 5 loudest Tracks")
plt.show()

# %% [markdown]
# ### Artist with the most danceability song

# %%
top_5_artists_danceable = df[["danceability","song_title","artist"]].sort_values(by="danceability",ascending=False)[:5]
top_5_artists_danceable
# Out:
#       danceability              song_title             artist
# 1433         0.984  Flashwind - Radio Edit       Ben Remember
# 1901         0.967                SexyBack  Justin Timberlake
# 604          0.962       Check Me Out Like          Blaqstarr
# 32           0.959             Best Friend         Young Thug
# 1957         0.959            Ice Ice Baby        Vanilla Ice

# %%
import plotly.express as px
fig = px.bar(top_5_artists_danceable,x="artist",y="danceability")
fig.show()
# Out:
# <div>                            <div id="eda07c06-97c1-4227-89ce-7b0bb408a70c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eda07c06-97c1-4227-89ce-7b0bb408a70c")) {                    Plotly.newPlot(                        "eda07c06-97c1-4227-89ce-7b0bb408a70c",                        [{"alignmentgroup":"True","hovertemplate":"artist=%{x}<br>danceability=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Ben Remember","Justin Timberlake","Blaqstarr","Young Thug","Vanilla Ice"],"xaxis":"x","y":[0.984,0.967,0.962,0.959,0.959],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":
# ...

# %% [markdown]
# ### Top 10 Instrumental Tracks

# %%
top_10_Instrumental_Tracks = df[["instrumentalness","song_title","artist"]].sort_values(by="instrumentalness",ascending=False)[:10]
top_10_Instrumental_Tracks
# Out:
#       instrumentalness                            song_title  \
# 1313             0.976                       Senseless Order
# 271              0.968  So Destroyed (channeling Rage Peace)
# 1575             0.964             A Hundred Dreams from Now
# 1619             0.958                                 Raven
# 725              0.957                     Strandbar (disko)
# 1546             0.956                        Almas vaggvisa
# 1322             0.955                            Pitchblack
# 1349             0.954                       Prismatic Abyss
# 1661             0.954                               Yebisah
# 121              0.952                        Chasing Heaven
#
#                         artist
# 1313        Signs of the Swarm
# 271                Prince Rama
# 1575                Ray Bryant
# 1619             John Dahlbäck
# 725                 Todd Terje
# 1546         Jan Lundgren Trio
# 1322  Walking Dead On Broadway
# 1349           Aversions Crown
# ...

# %%
import plotly.express as px
fig = px.pie(top_10_Instrumental_Tracks, values='instrumentalness', names='song_title')
fig.show()
# Out:
# <div>                            <div id="66625ae3-fa4f-4ab2-8353-13207c9326aa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("66625ae3-fa4f-4ab2-8353-13207c9326aa")) {                    Plotly.newPlot(                        "66625ae3-fa4f-4ab2-8353-13207c9326aa",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"song_title=%{label}<br>instrumentalness=%{value}<extra></extra>","labels":["Senseless Order","So Destroyed (channeling Rage Peace)","A Hundred Dreams from Now","Raven","Strandbar (disko)","Almas vaggvisa","Pitchblack","Prismatic Abyss","Yebisah","Chasing Heaven"],"legendgroup":"","name":"","showlegend":true,"values":[0.976,0.968,0.964,0.958,0.957,0.956,0.955,0.954,0.954,0.952],"type":"pie"}],               
# ...

# %% [markdown]
# ### Multiple feature plots

# %%
interest_feature_cols = ["tempo","loudness",'acousticness', 'danceability', 'duration_ms', 
                         'energy','instrumentalness','liveness', 'speechiness', 'valence']

# %%
for feature in interest_feature_cols:
    pos_data = df[df["target"]==1][feature]
    neg_data = df[df["target"]==0][feature]
    
    plt.figure(figsize=(12,7))
    
    sns.histplot(pos_data,bins=30,label='Positive',color='green',kde=True)
    sns.histplot(neg_data,bins=30,label='Negative',color='red',kde=True)
    
    plt.legend(loc="upper right")
    plt.title(f"Postive and Negative Histogram for {feature}")
    plt.show()
